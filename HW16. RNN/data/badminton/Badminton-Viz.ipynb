# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# d = pd.read_csv('001-M-badminton.csv')
d = pd.read_csv('002-F-badminton.csv')
# d = pd.read_csv('003-M-badminton.csv')
# d = pd.read_csv('004-M-badminton.csv')
# d = pd.read_csv('005-M-badminton.csv')
# d = pd.read_csv('006-M-badminton.csv')
# d = pd.read_csv('007-M-badminton.csv')
# d = pd.read_csv('008-M-badminton.csv')
# d = pd.read_csv('009-M-badminton.csv')
# d = pd.read_csv('010-M-badminton.csv')

# %%
d['wx'].plot()
d['wy'].plot()
d['wz'].plot()
plt.show()


d['nx'].plot()
d['ny'].plot()
d['nz'].plot()
plt.show()

d['tx'].plot()
d['ty'].plot()
d['tz'].plot()
plt.show()
