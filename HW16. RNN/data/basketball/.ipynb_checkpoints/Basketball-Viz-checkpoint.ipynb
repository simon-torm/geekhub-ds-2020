# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# d = pd.read_csv('001-M-basketball.csv')
d = pd.read_csv('002-F-basketball.csv')
# d = pd.read_csv('003-M-basketball.csv')
# d = pd.read_csv('004-M-basketball.csv')
# d = pd.read_csv('005-M-basketball.csv')
# d = pd.read_csv('006-M-basketball.csv')
# d = pd.read_csv('007-M-basketball.csv')
# d = pd.read_csv('008-M-basketball.csv')
# d = pd.read_csv('009-M-basketball.csv')
# d = pd.read_csv('010-M-basketball.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-c30a40f5b0bd> in <module>()
#       1 # d = pd.read_csv('001-M-cycling.csv')
# ----> 2 d = pd.read_csv('002-F-cycling.csv')
#       3 # d = pd.read_csv('003-M-cycling.csv')
#       4 # d = pd.read_csv('004-M-cycling.csv')
#       5 # d = pd.read_csv('005-M-cycling.csv')
#
# ...

# %%
d['wx'].plot()
d['wy'].plot()
d['wz'].plot()
plt.show()


d['nx'].plot()
d['ny'].plot()
d['nz'].plot()
plt.show()

d['tx'].plot()
d['ty'].plot()
d['tz'].plot()
plt.show()
